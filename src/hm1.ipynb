# %%
import re
import numpy as np

# %%
def number(f):
  i=0
  for line in f:
    if re.search('^>', line):
        i+=1
  return i

# %%
def total(f):
  sum=0
  for line in contig:
    if re.search('^>', line):
      found=re.search('len(.+?)_', line)
      sum+=int(found.group(1))
  return sum

# %%
conting_f = open('/content/sample_data/Poil_contig.fa')
f=conting_f.readlines()
print(f'Общее количество контингов: {number(f)}')
print(f'Общая длина контингов: {total(f)}')
# Out:
# Общее количество контингов: 606
# Общая длина контингов: 3924839

# %%
scaffold_f = open('/content/sample_data/Poil_scaffold.fa')
f=scaffold_f.readlines()
print(f'Общее количество скаффолдов: {number(f)}')
print(f'Общая длина скаффолдов: {total(f)}')
# Out:
# Общее количество скаффолдов: 71
# Общая длина скаффолдов: 3924839
